# %%
dbutils.help()
# Out:
# <div class = "ansiout">
# This module provides various utilities for users to interact with the rest of Databricks.
# ...

# %%
spark.conf.set("fs.azure.account.key.mylodlstorageaccount.blob.core.windows.net",
                 dbutils.secrets.get(scope ='adbsecretescope',key ='adbsecretkey'))

https://mylodlstorageaccount.blob.core.windows.net/pythontest

CHARLES OLAOYE.docx

# %%
tomtom_data = spark.read.csv("wasbs://pythontest@mylodlstorageaccount.blob.core.windows.net/tomtom2.csv",header ="true")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-1591136077848596> in <cell line: 1>()
# ----> 1 tomtom_data = spark.read.csv("wasbs://pythontest@mylodlstorageaccount.blob.core.windows.net/tomtom2.csv",header ="true")
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# ...

# %%
dbutils.fs.mount(source = 'wasbs://pythontest@mylodlstorageaccount.blob.core.windows.net',
    mount_point = "/mnt/",
    extra_configs = ("fs.azure.account.key.mylodlstorageaccount.blob.core.windows.net",
                 dbutils.secrets.get(scope ='adbsecretescope',key ='adbsecretkey')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-1591136077848597> in <cell line: 1>()
# ----> 1 dbutils.fs.mount(source = 'wasbs://pythontest@mylodlstorageaccount.blob.core.windows.net',
#       2     mount_point = "/mnt/",
#       3     extra_configs = ("fs.azure.account.key.mylodlstorageaccount.blob.core.windows.net",
#       4                  dbutils.secrets.get(scope ='adbsecretescope',key ='adbsecretkey')))
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     344             def f_with_exception_handling(*args, **kwargs):
#     345                 try:
# --> 346                     return f(*args, **kwargs)
#     347                 except Py4JJavaError as e:
#     348
#
# /databricks/python_shell/dbruntime/dbutils.py in mount(self, source, mount_point, encryption_type, owner, extra_configs)
# ...

# %%
dbutils.fs.refreshMounts()
# Out:
# Mounts successfully refreshed.
# Out[58]: True

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

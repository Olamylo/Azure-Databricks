# %%
import pandas as pd


df = pd.read_csv("/dbfs/FileStore/datasets/insurance.csv")
insurance_df = spark.createDataFrame(df)


# insurance_df.select('age','sex','bmi','region','charges').where((insurance_df['age'] >50) & (insurance_df['sex'] == 'female')).orderBy('charges').display()


region_cost = insurance_df.groupBy('region').agg({'charges':'sum'}).withColumnRenamed('sum(charges)','total_charges').orderBy('total_charges', ascending = False).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>total_charges</th></tr></thead><tbody><tr><td>southeast</td><td>5363689.76329</td></tr><tr><td>northeast</td><td>4343668.583308999</td></tr><tr><td>northwest</td><td>4035711.9965399993</td></tr><tr><td>southwest</td><td>4012754.6476200004</td></tr></tbody></table></div>

# %%
region_cost

# %%
region_cost = insurance_df.groupBy('region').agg({'charges':'sum'}).withColumnRenamed('sum(charges)','total_charges').orderBy('total_charges', ascending = False)

region_cost.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>total_charges</th></tr></thead><tbody><tr><td>southeast</td><td>5363689.76329</td></tr><tr><td>northeast</td><td>4343668.583308999</td></tr><tr><td>northwest</td><td>4035711.9965399993</td></tr><tr><td>southwest</td><td>4012754.6476200004</td></tr></tbody></table></div>

# %%
#  remove existing file if present
dbutils.fs.rm("/dbfs/FileStore/datasets/region_insurance_charges.csv",True)

# export to file
region_cost.write.csv("/dbfs/FileStore/datasets/region_insurance_charges.csv")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-3573459878455696> in <cell line: 5>()
#       3
#       4 # export to file
# ----> 5 region_cost.write.csv("/dbfs/FileStore/datasets/region_insurance_charges.csv")
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# ...

# %%
# new_df = pd.read_csv("/dbfs/FileStore/datasets/region_insurance_charges.csv")

# new_df.display()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <command-3573459878455697> in <cell line: 1>()
# ----> 1 new_df = pd.read_csv("/dbfs/FileStore/datasets/region_insurance_charges.csv")
#       2
#       3 new_df.display()
#
# /databricks/python/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
new_df = spark.read.format('csv').option("inferSchema", 'true').option("header", 'false').load("/dbfs/FileStore/datasets/region_insurance_charges.csv")

new_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th></tr></thead><tbody><tr><td>southeast</td><td>5363689.76329</td></tr><tr><td>northeast</td><td>4343668.583308999</td></tr><tr><td>northwest</td><td>4035711.9965399993</td></tr><tr><td>southwest</td><td>4012754.6476200004</td></tr></tbody></table></div>

# %%
#  remove existing file if present
dbutils.fs.rm("/dbfs/FileStore/datasets/region_insurance_charges.json",True)

# export to file
new_df.write.csv("/dbfs/FileStore/datasets/region_insurance_charges.json")

# %%
#remove folder
# dbutils.fs.rm("/dbfs/FileStore/datasets", True)
# Out:
# Out[22]: True
